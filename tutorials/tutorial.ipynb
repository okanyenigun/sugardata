# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
from sugardata.sentiment import SentimentGenerator

generator = SentimentGenerator(provider="openai", model="gpt-4o-mini", batch_size=32, temperature=0.9, output_type="pandas", language="en")

# %%
results = generator.generate("Iphone", n=200)

# %%
results = generator.generate("M1 Chip", n=100)

# %%
results
# Out:
#                                                   text  id  concept     label  \
# 0    With the latest iPhone release, Apple has once...   0   Iphone  positive
# 1    Not sure why everyone’s hyping Augmented Reali...   1   Iphone  negative
# 2    "Ever since I got my iPhone, it feels like I’m...   2   Iphone  positive
# 3    As much as I wanted to love my iPhone and the ...   3   Iphone  negative
# 4    Despite the iPhone's continued dominance in mo...   4   Iphone  negative
# ..                                                 ...  ..      ...       ...
# 195  While the M1 Chip dazzles with impressive perf...  95  M1 Chip  negative
# 196  Honestly, while the M1 chip is powerful and al...  96  M1 Chip  negative
# 197  Honestly, while the M1 chip has some impressiv...  97  M1 Chip  negative
# 198  The M1 Chip's ARM architecture delivers unpara...  98  M1 Chip  positive
# 199  Despite its advanced Neural Engine capabilitie...  99  M1 Chip  negative
#
# ...
